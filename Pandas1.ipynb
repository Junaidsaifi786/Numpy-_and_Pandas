# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\hp\Downloads\Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull()
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False    False       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False     True       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False     True       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False     True       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5501
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
null_value = df.isnull().sum().sum()

# %%
null_value
# Out:
# 6200

# %%
total_value = df.shape[0]

# %%
total_value
# Out:
# 13320

# %%
per = (null_value*100)/total_value

# %%
per
# Out:
# 46.546546546546544

# %%
soc_null_val = df['society'].isnull().sum()

# %%
soc_null_val
# Out:
# 5501

# %%
per_of_sc_val = (soc_null_val*100)/null_value

# %%
per_of_sc_val
# Out:
# 88.7258064516129

# %%
#handle missing value

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df[df['bath']>2]
# Out:
#                   area_type   availability            location       size  \
# 1                Plot  Area  Ready To Move    Chikka Tirupathi  4 Bedroom
# 3      Super built-up  Area  Ready To Move  Lingadheeranahalli      3 BHK
# 6      Super built-up  Area         18-May    Old Airport Road      4 BHK
# 7      Super built-up  Area  Ready To Move        Rajaji Nagar      4 BHK
# 8      Super built-up  Area  Ready To Move        Marathahalli      3 BHK
# ...                     ...            ...                 ...        ...
# 13311            Plot  Area  Ready To Move    Ramamurthy Nagar  7 Bedroom
# 13314  Super built-up  Area  Ready To Move   Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move          Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move       Richards Town      4 BHK
# 13318  Super built-up  Area         18-Jun     Padmanabhanagar      4 BHK
#
#        society total_sqft  bath  balcony   price
# ...

# %%
df[df['bath']>2][['location','balcony','price']]
# Out:
#                  location  balcony   price
# 1        Chikka Tirupathi      3.0  120.00
# 3      Lingadheeranahalli      1.0   95.00
# 6        Old Airport Road      NaN  204.00
# 7            Rajaji Nagar      NaN  600.00
# 8            Marathahalli      1.0   63.25
# ...                   ...      ...     ...
# 13311    Ramamurthy Nagar      2.0  250.00
# 13314   Green Glen Layout      3.0  112.00
# 13315          Whitefield      0.0  231.00
# 13316       Richards Town      NaN  400.00
# 13318     Padmanabhanagar      1.0  488.00
#
# [5551 rows x 3 columns]

# %%
#wap to find the price of the house having location Electronic city phase II
df['location']
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 2                     Uttarahalli
# 3              Lingadheeranahalli
# 4                        Kothanur
#                    ...
# 13315                  Whitefield
# 13316               Richards Town
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# 13319                Doddathoguru
# Name: location, Length: 13320, dtype: object

# %%
df[df['location']=='Electronic City Phase']
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price]
# Index: []

# %%
# wap to find a house which is 'ready to move' having location 
# 'whitefield' with having compulsory of min. 2 balcony.
